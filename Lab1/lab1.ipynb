# %% [markdown]
# # install all librarys

# %%
#!pip install scipy opencv-python scikit-image pillow matplotlib

# %% [markdown]
# # Loading and Visuaizing Image

# %% [markdown]
# ## loading/reading image using OpenCv

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("IAU_Logo.jpeg")
print(img.shape)
plt.imshow(img)
plt.axis("off")
# Out:
# (800, 800, 3)
# (-0.5, 799.5, 799.5, -0.5)

# %% [markdown]
# ## Loding/reading inage using PIL

# %%
from PIL import Image
import matplotlib.cm as cm
#
imag2 = Image.open("KFUPM_logo.png")
print(imag2.size)
plt.axis("off")
plt.imshow(imag2)
# Out:
# (233, 216)

# %% [markdown]
# # Image Storing

# %% [markdown]
# ## a.	Saving image to disc using OpenCV

# %%
cv2.imwrite("Not_KFUPM_logo.png", img)
# Out:
# True

# %% [markdown]
# ##  b.	Saving image to disc using PIL

# %%
imag2.save("Not_IAU_logo.png")

# %% [markdown]
# # Display image as an Array

# %%
import numpy as np  
print(f" the shape of IAU image is {img.shape}")
print(img.dtype)
# becuase the imag2 not np array so we need to convert it to np array to use "shape"
imag2 = np.array(imag2)
print(f" the shape of KFUPM image is {imag2.shape}")
# Out:
#  the shape of IAU image is (800, 800, 3)
# uint8
#  the shape of KFUPM image is (216, 233)

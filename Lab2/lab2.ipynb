# %% [markdown]
# # Step 1
#  Import the libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Step 2
#  Define Functions

# %%
def sample_image(image, factor):
    """
    Downsamples the image by the given factor.
    Args:
        image (numpy array): Original image.
        factor (int): Factor by which to downsample.
    Returns:
        numpy array: Downsampled image.
    """
    H, w = image.shape[:2]
    SampleImage = cv2.resize(image, (w // factor, H // factor), interpolation=cv2.INTER_NEAREST)
    
    return SampleImage
    

def quantize_image(image, levels):
    """
    Reduces the number of grayscale levels in the image.
    Args:
        image (numpy array): Original image.
        levels (int): Number of grayscale levels.
    Returns:
        numpy array: Quantized image.
    """
    QuantizedImage = np.floor(image / (256 // levels)) * (256 // levels)
    QuantizedImage = QuantizedImage.astype(np.uint8)
    return QuantizedImage

def plot_images(original, sampled, quantized):
    """
    Plots the original, sampled, and quantized images side by side.
    Args:
        original (numpy array): Original image.
        sampled (numpy array): Sampled image.
        quantized (numpy array): Quantized image.
    """
    print(original.shape)
    plt.figure(figsize=(12, 4))
    plt.subplot(1, 3, 1)
    plt.imshow(original, cmap='gray')
    plt.title('Original Image')
    plt.axis('off')

    plt.subplot(1, 3, 2)
    plt.imshow(sampled, cmap='gray')
    plt.title('Sampled Image')
    plt.axis('off')

    plt.subplot(1, 3, 3)
    plt.imshow(quantized, cmap='gray')
    plt.title('Quantized Image')
    plt.axis('off')

    plt.show()

# %% [markdown]
# # Step 3
#  Import the image and set the parameters

# %%
image_path='cat.png'
sampling_factor=14
quantization_levels=9

# Load image in grayscale
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
if original_image is None:
    print(f"Error: Unable to load image at {image_path}")

# Sample and quantize
sampled_image = sample_image(original_image, sampling_factor)
quantized_image = quantize_image(original_image, quantization_levels)

# Plot results
plot_images(original_image, sampled_image, quantized_image)



# Arithmetic Operations

from PIL import Image
img1=Image.open('cat_gray.png')
img2=Image.open ('shoebill.png')

resize=(400,400)
img1=img1.resize(resize,Image.Resampling.LANCZOS)
img2=img2.resize(resize,Image.Resampling.LANCZOS)

im1arr=np.asarray(img1)
im2arr=np.asarray(img2)

addition=im1arr+im2arr
resultImage=Image.fromarray(addition)
resultImage.show()

#Sets and Logical Operations

img3=Image.open('macaw_bird.jpg')
img3.show()
img4=Image.open('Cat Hungry1.jpg')
img4.show()

resize=(400,400)
img3=img3.resize(resize,Image.Resampling.LANCZOS)
img4=img4.resize(resize,Image.Resampling.LANCZOS)

im3arr=np.asarray(img3)
im4arr=np.asarray(img4)

union=im4arr|im3arr
resultImage2=Image.fromarray(union)
resultImage2.show()
# Out:
# (446, 452)

# %% [markdown]
# # Task 1
#  Change the sampling and quantization parameters and observe the effects.

# %%
image_path='cat.png'
sampling_factor=1
quantization_levels=1

# Load image in grayscale
original_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
if original_image is None:
    print(f"Error: Unable to load image at {image_path}")

# Sample and quantize
sampled_image = sample_image(original_image, sampling_factor)
quantized_image = quantize_image(original_image, quantization_levels)

# Plot results
plot_images(original_image, sampled_image, quantized_image)
# Out:
# (446, 452)

# %% [markdown]
# # Task2
#  Read two images, convert them into an array, and perform the following operations on them.
# 1.	Subtract two images and display the result.
# 2.	Add one image with a constant value of 175 and display it.
# 3.	Apply the set difference operation on two Gray-Scale images.
# 4.	Apply the symmetric difference operation on two Gray-Scale images.
# 5.	Apply Intersection operations on two Gray-Scale images.

# %%
from PIL import Image
from matplotlib.pyplot import step
img1=Image.open('cat_gray.png')
img2=Image.open ('shoebill.png')

resize=(400,400)
img1=img1.resize(resize,Image.Resampling.LANCZOS)
img2=img2.resize(resize,Image.Resampling.LANCZOS)

im1arr=np.asarray(img1)
im2arr=np.asarray(img2)

# step1

subtraction = np.clip(im1arr - im2arr, 0, 255)
resultImage = Image.fromarray(subtraction.astype(np.uint8))
resultImage.show()


# step2

addtoim1arr=im1arr +175
resultImage=Image.fromarray(addtoim1arr)
resultImage.show()

# #step3

img1 = Image.open('cat_gray.png').convert('L')
img2 = Image.open('shoebill.png').convert('L')
resize=(400,400)
img1=img1.resize(resize,Image.Resampling.LANCZOS)
img2=img2.resize(resize,Image.Resampling.LANCZOS)

im1arr = np.asarray(img1)
im2arr = np.asarray(img2)

diff_image = cv2.absdiff(im1arr, im2arr)

cv2.imshow('Correct Set Difference', diff_image)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# step 4

diff = cv2.absdiff(im1arr, im2arr)


if np.any(diff): 
    print("Images are NOT the same")
else:
    print("Images are exactly the same")


cv2.imshow('Symmetric Difference Result', diff)
cv2.waitKey(0)
cv2.destroyAllWindows()

# step 5

img_bwa = cv2.bitwise_and(im1arr, im2arr)
cv2.imshow('Bitwise AND', img_bwa)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Images are NOT the same
